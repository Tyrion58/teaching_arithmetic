# %%
from test_utils import model_addition_tester

device = 'cuda'
model_path = 'out/out-add-from-judge-mix-data/ckpt_judge_acc.pt'
tester = model_addition_tester(
    model_path=model_path,
    test_file='./data/bal/test_3digit_10000.txt',
    mydevice=device,
    data_format='eval_format',
    judge=True,
    label_exp=True
)
# Out:
# number of parameters: 10.66M
# Loading meta from meta_all_ascii_chars.pkl...

# %%
tester.test_addition()
# Out:
# evaluating addition from: FILE:./data/bal/test_3digit_10000.txt
# Evaluating Addition using test data file: ./data/bal/test_3digit_10000.txt
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:00<00:00, 16501.58it/s]
#  15%|█▌        | 12/80 [00:00<00:01, 59.18it/s]
# outputs(x):  Te(807+590):1497T
# wrong  : 807+590=1497
# correct: 807+590=1397
# outputs(x):  Te(766+136):802T
#
# wrong  : 766+136=802
# correct: 766+136=902
# outputs(x):  Te(640+959):1699T
# wrong  : 640+959=1699
# correct: 640+959=1599
# outputs(x):  Te(402+298):600T
#
# wrong  : 402+298=600
# correct: 402+298=700
# outputs(x):  Te(832+865):1797T
# wrong  : 832+865=1797
# correct: 832+865=1697
# outputs(x):  Te(257+841):1198T
# wrong  : 257+841=1198
# correct: 257+841=1098
# outputs(x):  Te(166+333):599T
#
# wrong  : 166+333=599
# correct: 166+333=499
#  30%|███       | 24/80 [00:00<00:00, 59.05it/s]
# outputs(x):  Te(889+660):1546T
# wrong  : 889+660=1546
# correct: 889+660=1549
# outputs(x):  Te(834+862):1796T
# wrong  : 834+862=1796
# correct: 834+862=1696
# outputs(x):  Te(599+309):808T
#
# wrong  : 599+309=808
# correct: 599+309=908
# outputs(x):  Te(830+866):1796T
# wrong  : 830+866=1796
# correct: 830+866=1696
# outputs(x):  Te(591+509):1000T
# wrong  : 591+509=1000
# correct: 591+509=1100
# outputs(x):  Te(259+181):4450T
# wrong  : 259+181=4450
# correct: 259+181=440
# outputs(x):  Te(222+677):999T
#
# wrong  : 222+677=999
# correct: 222+677=899
#  45%|████▌     | 36/80 [00:00<00:00, 59.25it/s]
# outputs(x):  Te(616+188):704T
#
# wrong  : 616+188=704
# correct: 616+188=804
# outputs(x):  Te(915+953):1858T
# wrong  : 915+953=1858
# correct: 915+953=1868
# outputs(x):  Te(323+974):1397T
# wrong  : 323+974=1397
# correct: 323+974=1297
# outputs(x):  Te(917+582):1599T
# wrong  : 917+582=1599
# correct: 917+582=1499
# outputs(x):  Te(683+118):701T
#
# wrong  : 683+118=701
# correct: 683+118=801
# outputs(x):  Te(340+539):8789F
# wrong  : 340+539=8789
# correct: 340+539=879
# outputs(x):  Te(267+530):897T
#
# wrong  : 267+530=897
# correct: 267+530=797
# outputs(x):  Te(502+399):801T
#
# wrong  : 502+399=801
# correct: 502+399=901
#  64%|██████▍   | 51/80 [00:00<00:00, 67.49it/s]
# outputs(x):  Te(184+616):700T
#
# wrong  : 184+616=700
# correct: 184+616=800
# outputs(x):  Te(477+423):800T
#
# wrong  : 477+423=800
# correct: 477+423=900
# outputs(x):  Te(818+381):1299T
# wrong  : 818+381=1299
# correct: 818+381=1199
# outputs(x):  Te(157+336):593T
#
# wrong  : 157+336=593
# correct: 157+336=493
# outputs(x):  Te(973+927):1800T
# wrong  : 973+927=1800
# correct: 973+927=1900
# outputs(x):  Te(373+923):1396T
# wrong  : 373+923=1396
# correct: 373+923=1296
#  84%|████████▍ | 67/80 [00:01<00:00, 71.21it/s]
# outputs(x):  Te(878+821):1799T
# wrong  : 878+821=1799
# correct: 878+821=1699
# outputs(x):  Te(117+486):503T
#
# wrong  : 117+486=503
# correct: 117+486=603
# outputs(x):  Te(327+377):604T
#
# wrong  : 327+377=604
# correct: 327+377=704
# outputs(x):  Te(925+474):1499T
# wrong  : 925+474=1499
# correct: 925+474=1399
# outputs(x):  Te(924+571):1595T
# wrong  : 924+571=1595
# correct: 924+571=1495
# outputs(x):  Te(935+864):1899T
# wrong  : 935+864=1899
# correct: 935+864=1799
# outputs(x):  Te(614+69):682T
#
# wrong  : 614+69=682
# correct: 614+69=683
# outputs(x):  Te(489+20):519T
#
# wrong  : 489+20=519
# correct: 489+20=509
# outputs(x):  Te(615+47):652T
#
# wrong  : 615+47=652
# correct: 615+47=662
# outputs(x):  Te(356+50):306T
#
# wrong  : 356+50=306
# correct: 356+50=406
# outputs(x):  Te(436+80):416T
#
# wrong  : 436+80=416
# correct: 436+80=516
# outputs(x):  Te(626+76):782T
#
# wrong  : 626+76=782
# correct: 626+76=702
# outputs(x):  Te(271+28):399T
#
# wrong  : 271+28=399
# correct: 271+28=299
# outputs(x):  Te(36+276):310T
#
# wrong  : 36+276=310
# correct: 36+276=312
# outputs(x):  Te(272+38):300T
#
# wrong  : 272+38=300
# correct: 272+38=310
# outputs(x):  Te(222+74):396T
#
# wrong  : 222+74=396
# correct: 222+74=296
# outputs(x):  Te(990+64):1044T
# wrong  : 990+64=1044
# correct: 990+64=1054
# outputs(x):  Te(432+97):539T
#
# wrong  : 432+97=539
# correct: 432+97=529
# outputs(x):  Te(178+28):296T
#
# wrong  : 178+28=296
# correct: 178+28=206
# outputs(x):  Te(596+37):623T
#
# wrong  : 596+37=623
# correct: 596+37=633
# outputs(x):  Te(101+90):291T
#
# wrong  : 101+90=291
# correct: 101+90=191
# outputs(x):  Te(487+66):543T
#
# wrong  : 487+66=543
# correct: 487+66=553
# outputs(x):  Te(991+84):1085T
# wrong  : 991+84=1085
# correct: 991+84=1075
# outputs(x):  Te(808+24):842T
#
# wrong  : 808+24=842
# correct: 808+24=832
# outputs(x):  Te(969+23):1002T
# wrong  : 969+23=1002
# correct: 969+23=992
# outputs(x):  Te(176+37):203T
#
# wrong  : 176+37=203
# correct: 176+37=213
# outputs(x):  Te(617+38):645T
#
# wrong  : 617+38=645
# correct: 617+38=655
# outputs(x):  Te(598+62):650T
#
# wrong  : 598+62=650
# correct: 598+62=660
# outputs(x):  Te(309+90):409T
#
# wrong  : 309+90=409
# correct: 309+90=399
# outputs(x):  Te(470+10):580T
#
# wrong  : 470+10=580
# correct: 470+10=480
# outputs(x):  Te(368+19):487T
#
# wrong  : 368+19=487
# correct: 368+19=387
# outputs(x):  Te(304+67):381T
#
# wrong  : 304+67=381
# correct: 304+67=371
# outputs(x):  Te(176+36):202T
#
# wrong  : 176+36=202
# correct: 176+36=212
# outputs(x):  Te(985+14):908T
#
# wrong  : 985+14=908
# correct: 985+14=999
# outputs(x):  Te(933+17):940T
#
# wrong  : 933+17=940
# correct: 933+17=950
# outputs(x):  Te(808+65):863T
#
# wrong  : 808+65=863
# correct: 808+65=873
# outputs(x):  Te(185+75):250T
#
# wrong  : 185+75=250
# correct: 185+75=260
# outputs(x):  Te(287+86):363T
#
# wrong  : 287+86=363
# correct: 287+86=373
# outputs(x):  Te(33+869):892T
#
# wrong  : 33+869=892
# correct: 33+869=902
# outputs(x):  Te(276+13):299T
#
# wrong  : 276+13=299
# correct: 276+13=289
# outputs(x):  Te(383+94):487T
#
# wrong  : 383+94=487
# correct: 383+94=477
# outputs(x):  Te(385+92):487T
#
# wrong  : 385+92=487
# correct: 385+92=477
# outputs(x):  Te(388+89):472T
#
# wrong  : 388+89=472
# correct: 388+89=477
# outputs(x):  Te(152+48):190T
#
# wrong  : 152+48=190
# correct: 152+48=200
# outputs(x):  Te(625+74):789T
#
# wrong  : 625+74=789
# correct: 625+74=699
# outputs(x):  Te(370+28):498T
#
# wrong  : 370+28=498
# correct: 370+28=398
# outputs(x):  Te(366+28):384T
#
# wrong  : 366+28=384
# correct: 366+28=394
# outputs(x):  Te(758+43):791T
#
# wrong  : 758+43=791
# correct: 758+43=801
# outputs(x):  Te(966+41):1017T
# wrong  : 966+41=1017
# correct: 966+41=1007
# outputs(x):  Te(696+39):745T
#
# wrong  : 696+39=745
# correct: 696+39=735
# outputs(x):  Te(605+69):664T
#
# wrong  : 605+69=664
# correct: 605+69=674
# outputs(x):  Te(495+94):599T
#
# wrong  : 495+94=599
# correct: 495+94=589
# outputs(x):  Te(698+50):758T
#
# wrong  : 698+50=758
# correct: 698+50=748
# outputs(x):  Te(545+47):692T
#
# wrong  : 545+47=692
# correct: 545+47=592
# outputs(x):  Te(599+40):649T
#
# wrong  : 599+40=649
# correct: 599+40=639
# outputs(x):  Te(249+26):265T
#
# wrong  : 249+26=265
# correct: 249+26=275
# outputs(x):  Te(899+63):952T
#
# wrong  : 899+63=952
# correct: 899+63=962
# outputs(x):  Te(857+53):800T
#
# wrong  : 857+53=800
# correct: 857+53=910
# outputs(x):  Te(752+58):800T
#
# wrong  : 752+58=800
# correct: 752+58=810
# outputs(x):  Te(721+89):800T
#
# wrong  : 721+89=800
# correct: 721+89=810
# outputs(x):  Te(227+80):217T
#
# wrong  : 227+80=217
# correct: 227+80=307
# outputs(x):  Te(785+73):868T
#
# wrong  : 785+73=868
# correct: 785+73=858
# outputs(x):  Te(399+50):459T
#
# wrong  : 399+50=459
# correct: 399+50=449
# outputs(x):  Te(857+38):885T
#
# wrong  : 857+38=885
# correct: 857+38=895
# outputs(x):  Te(421+85):406T
#
# wrong  : 421+85=406
# correct: 421+85=506
# outputs(x):  Te(937+96):1023T
# wrong  : 937+96=1023
# correct: 937+96=1033
# outputs(x):  Te(166+30):296T
#
# wrong  : 166+30=296
# correct: 166+30=196
# outputs(x):  Te(586+19):595T
#
# wrong  : 586+19=595
# correct: 586+19=605
# outputs(x):  Te(132+34):176T
#
# wrong  : 132+34=176
# correct: 132+34=166
# outputs(x):  Te(15+793):708T
#
# wrong  : 15+793=708
# correct: 15+793=808
# outputs(x):  Te(213+88):201T
#
# wrong  : 213+88=201
# correct: 213+88=301
# outputs(x):  Te(609+56):655T
#
# wrong  : 609+56=655
# correct: 609+56=665
# outputs(x):  Te(826+68):914T
#
# wrong  : 826+68=914
# correct: 826+68=894
# outputs(x):  Te(93+809):802T
#
# wrong  : 93+809=802
# correct: 93+809=902
# outputs(x):  Te(808+89):997T
#
# wrong  : 808+89=997
# correct: 808+89=897
# outputs(x):  Te(759+33):882T
#
# wrong  : 759+33=882
# correct: 759+33=792
# outputs(x):  Te(360+41):301T
#
# wrong  : 360+41=301
# correct: 360+41=401
# outputs(x):  Te(835+71):806T
#
# wrong  : 835+71=806
# correct: 835+71=906
# outputs(x):  Te(657+97):764T
#
# wrong  : 657+97=764
# correct: 657+97=754
# outputs(x):  Te(875+62):947T
#
# wrong  : 875+62=947
# correct: 875+62=937
# outputs(x):  Te(870+70):930T
#
# wrong  : 870+70=930
# correct: 870+70=940
# outputs(x):  Te(934+82):1006T
# wrong  : 934+82=1006
# correct: 934+82=1016
# outputs(x):  Te(34+905):949T
#
# wrong  : 34+905=949
# correct: 34+905=939
# outputs(x):  Te(886+53):949T
#
# wrong  : 886+53=949
# correct: 886+53=939
# outputs(x):  Te(978+13):981T
#
# wrong  : 978+13=981
# correct: 978+13=991
# outputs(x):  Te(605+95):600T
#
# wrong  : 605+95=600
# correct: 605+95=700
# outputs(x):  Te(851+29):870T
#
# wrong  : 851+29=870
# correct: 851+29=880
# outputs(x):  Te(869+27):906T
#
# wrong  : 869+27=906
# correct: 869+27=896
# outputs(x):  Te(914+88):902T
#
# wrong  : 914+88=902
# correct: 914+88=1002
# outputs(x):  Te(19+979):1098T
# wrong  : 19+979=1098
# correct: 19+979=998
# outputs(x):  Te(408+27):425T
#
# wrong  : 408+27=425
# correct: 408+27=435
# outputs(x):  Te(396+37):423T
#
# wrong  : 396+37=423
# correct: 396+37=433
# outputs(x):  Te(633+38):661T
#
# wrong  : 633+38=661
# correct: 633+38=671
# outputs(x):  Te(679+28):607T
#
# wrong  : 679+28=607
# correct: 679+28=707
# outputs(x):  Te(741+19):750T
#
# wrong  : 741+19=750
# correct: 741+19=760
# outputs(x):  Te(403+59):452T
#
# wrong  : 403+59=452
# correct: 403+59=462
# outputs(x):  Te(289+63):342T
#
# wrong  : 289+63=342
# correct: 289+63=352
# outputs(x):  Te(916+34):940T
#
# wrong  : 916+34=940
# correct: 916+34=950
# outputs(x):  Te(804+67):861T
#
# wrong  : 804+67=861
# correct: 804+67=871
# outputs(x):  Te(935+37):962T
#
# wrong  : 935+37=962
# correct: 935+37=972
# outputs(x):  Te(908+32):930T
#
# wrong  : 908+32=930
# correct: 908+32=940
# outputs(x):  Te(199+76):265T
#
# wrong  : 199+76=265
# correct: 199+76=275
# outputs(x):  Te(383+14):407T
#
# wrong  : 383+14=407
# correct: 383+14=397
# outputs(x):  Te(918+68):996T
#
# wrong  : 918+68=996
# correct: 918+68=986
# outputs(x):  Te(973+36):1019T
# wrong  : 973+36=1019
# correct: 973+36=1009
# outputs(x):  Te(285+85):360T
#
# wrong  : 285+85=360
# correct: 285+85=370
# outputs(x):  Te(276+28):294T
#
# wrong  : 276+28=294
# correct: 276+28=304
# outputs(x):  Te(480+18):598T
#
# wrong  : 480+18=598
# correct: 480+18=498
# outputs(x):  Te(13+123):126T
#
# wrong  : 13+123=126
# correct: 13+123=136
# outputs(x):  Te(842+99):931T
#
# wrong  : 842+99=931
# correct: 842+99=941
# outputs(x):  Te(92+817):919T
#
# wrong  : 92+817=919
# correct: 92+817=909
# outputs(x):  Te(213+97):200T
#
# wrong  : 213+97=200
# correct: 213+97=310
# outputs(x):  Te(199+79):275T
#
# wrong  : 199+79=275
# correct: 199+79=278
# outputs(x):  Te(669+66):725T
#
# wrong  : 669+66=725
# correct: 669+66=735
# outputs(x):  Te(663+57):740T
#
# wrong  : 663+57=740
# correct: 663+57=720
# outputs(x):  Te(493+79):562T
#
# wrong  : 493+79=562
# correct: 493+79=572
# outputs(x):  Te(229+39):368T
#
# wrong  : 229+39=368
# correct: 229+39=268
# outputs(x):  Te(491+29):510T
#
# wrong  : 491+29=510
# correct: 491+29=520
# outputs(x):  Te(936+37):963T
#
# wrong  : 936+37=963
# correct: 936+37=973
# outputs(x):  Te(294+95):359T
#
# wrong  : 294+95=359
# correct: 294+95=389
# outputs(x):  Te(226+58):294T
#
# wrong  : 226+58=294
# correct: 226+58=284
# outputs(x):  Te(539+40):589T
#
# wrong  : 539+40=589
# correct: 539+40=579
# outputs(x):  Te(989+89):1088T
# wrong  : 989+89=1088
# correct: 989+89=1078
# outputs(x):  Te(336+35):361T
#
# wrong  : 336+35=361
# correct: 336+35=371
# outputs(x):  Te(296+19):305T
#
# wrong  : 296+19=305
# correct: 296+19=315
# outputs(x):  Te(565+31):597T
#
# wrong  : 565+31=597
# correct: 565+31=596
# outputs(x):  Te(593+26):629T
#
# wrong  : 593+26=629
# correct: 593+26=619
# outputs(x):  Te(366+84):490T
#
# wrong  : 366+84=490
# correct: 366+84=450
# outputs(x):  Te(836+15):841T
#
# wrong  : 836+15=841
# correct: 836+15=851
# outputs(x):  Te(102+96):298T
#
# wrong  : 102+96=298
# correct: 102+96=198
# 100%|██████████| 80/80 [00:01<00:00, 67.35it/s]
# outputs(x):  Te(145+66):1011T
# wrong  : 145+66=1011
# correct: 145+66=211
# outputs(x):  Te(766+36):812T
#
# wrong  : 766+36=812
# correct: 766+36=802
# outputs(x):  Te(484+97):571T
#
# wrong  : 484+97=571
# correct: 484+97=581
# outputs(x):  Te(109+85):294T
#
# wrong  : 109+85=294
# correct: 109+85=194
# outputs(x):  Te(942+67):1019T
# wrong  : 942+67=1019
# correct: 942+67=1009
# outputs(x):  Te(779+39):808T
#
# wrong  : 779+39=808
# correct: 779+39=818
# outputs(x):  Te(136+70):1006T
# wrong  : 136+70=1006
# correct: 136+70=206
# outputs(x):  Te(864+26):880T
#
# wrong  : 864+26=880
# correct: 864+26=890
# outputs(x):  Te(926+69):1005T
# wrong  : 926+69=1005
# correct: 926+69=995
# outputs(x):  Te(695+87):792T
#
# wrong  : 695+87=792
# correct: 695+87=782
# outputs(x):  Te(871+79):940T
#
# wrong  : 871+79=940
# correct: 871+79=950
# outputs(x):  Te(17+396):412T
#
# wrong  : 17+396=412
# correct: 17+396=413
# outputs(x):  Te(293+79):362T
#
# wrong  : 293+79=362
# correct: 293+79=372
# outputs(x):  Te(157+21):188T
#
# wrong  : 157+21=188
# correct: 157+21=178
# outputs(x):  Te(735+69):794T
#
# wrong  : 735+69=794
# correct: 735+69=804
# outputs(x):  Te(278+11):299T
#
# wrong  : 278+11=299
# correct: 278+11=289
# outputs(x):  Te(949+91):940T
#
# wrong  : 949+91=940
# correct: 949+91=1040
# outputs(x):  Te(815+93):808T
#
# wrong  : 815+93=808
# correct: 815+93=908
# outputs(x):  Te(891+39):920T
#
# wrong  : 891+39=920
# correct: 891+39=930
# outputs(x):  Te(524+69):693T
#
# wrong  : 524+69=693
# correct: 524+69=593
# outputs(x):  Te(592+28):610T
#
# wrong  : 592+28=610
# correct: 592+28=620
# outputs(x):  Te(858+42):890T
#
# wrong  : 858+42=890
# correct: 858+42=900
# outputs(x):  Te(706+98):704T
#
# wrong  : 706+98=704
# correct: 706+98=804
# outputs(x):  Te(992+71):1003T
# wrong  : 992+71=1003
# correct: 992+71=1063
# outputs(x):  Te(203+57):250T
#
# wrong  : 203+57=250
# correct: 203+57=260
# outputs(x):  Te(894+67):951T
#
# wrong  : 894+67=951
# correct: 894+67=961
# outputs(x):  Te(838+54):882T
#
# wrong  : 838+54=882
# correct: 838+54=892
# outputs(x):  Te(858+48):896T
#
# wrong  : 858+48=896
# correct: 858+48=906
# outputs(x):  Te(448+55):403T
#
# wrong  : 448+55=403
# correct: 448+55=503
# outputs(x):  Te(827+59):885T
#
# wrong  : 827+59=885
# correct: 827+59=886
# outputs(x):  Te(798+63):851T
#
# wrong  : 798+63=851
# correct: 798+63=861
# outputs(x):  Te(168+62):220T
#
# wrong  : 168+62=220
# correct: 168+62=230
# outputs(x):  Te(699+87):796T
#
# wrong  : 699+87=796
# correct: 699+87=786
# outputs(x):  Te(973+25):1008T
# wrong  : 973+25=1008
# correct: 973+25=998
# outputs(x):  Te(538+92):620T
#
# wrong  : 538+92=620
# correct: 538+92=630
# outputs(x):  Te(457+43):490T
#
# wrong  : 457+43=490
# correct: 457+43=500
# outputs(x):  Te(188+21):109T
#
# wrong  : 188+21=109
# correct: 188+21=209
# outputs(x):  Te(646+36):672T
#
# wrong  : 646+36=672
# correct: 646+36=682
# outputs(x):  Te(712+97):709T
#
# wrong  : 712+97=709
# correct: 712+97=809
# outputs(x):  Te(148+73):121T
#
# wrong  : 148+73=121
# correct: 148+73=221
# outputs(x):  Te(505+25):520T
#
# wrong  : 505+25=520
# correct: 505+25=530
# outputs(x):  Te(105+57):262T
#
# wrong  : 105+57=262
# correct: 105+57=162
# outputs(x):  Te(314+6):310T
#
# wrong  : 314+6=310
# correct: 314+6=320
# outputs(x):  Te(233+0):23T
# j
# wrong  : 233+0=23
# correct: 233+0=233
# outputs(x):  Te(929+2):921T
#
# wrong  : 929+2=921
# correct: 929+2=931
# outputs(x):  Te(8+392):490T
#
# wrong  : 8+392=490
# correct: 8+392=400
# outputs(x):  Te(110+7):116T
#
# wrong  : 110+7=116
# correct: 110+7=117
# outputs(x):  Te(806+3):819T
#
# wrong  : 806+3=819
# correct: 806+3=809
# outputs(x):  Te(416+4):410T
#
# wrong  : 416+4=410
# correct: 416+4=420
# outputs(x):  Te(3+617):610T
#
# wrong  : 3+617=610
# correct: 3+617=620
# outputs(x):  Te(9+554):663T
#
# wrong  : 9+554=663
# correct: 9+554=563
# outputs(x):  Te(858+6):854T
#
# wrong  : 858+6=854
# correct: 858+6=864
# outputs(x):  Te(918+5):913T
#
# wrong  : 918+5=913
# correct: 918+5=923
# outputs(x):  Te(3+817):810T
#
# wrong  : 3+817=810
# correct: 3+817=820
# outputs(x):  Te(128+4):122T
#
# wrong  : 128+4=122
# correct: 128+4=132
# outputs(x):  Te(577+0):57T
# j
# wrong  : 577+0=57
# correct: 577+0=577
# outputs(x):  Te(24+55):789T
#
# wrong  : 24+55=789
# correct: 24+55=79
# outputs(x):  Te(498+6):414T
#
# wrong  : 498+6=414
# correct: 498+6=504
# outputs(x):  Te(197+7):194T
#
# wrong  : 197+7=194
# correct: 197+7=204
# outputs(x):  Te(693+9):692T
#
# wrong  : 693+9=692
# correct: 693+9=702
# outputs(x):  Te(126+4):120T
#
# wrong  : 126+4=120
# correct: 126+4=130
# outputs(x):  Te(3+688):791T
#
# wrong  : 3+688=791
# correct: 3+688=691
# outputs(x):  Te(129+9):228T
#
# wrong  : 129+9=228
# correct: 129+9=138
# outputs(x):  Te(417+4):411T
#
# wrong  : 417+4=411
# correct: 417+4=421
# outputs(x):  Te(597+6):593T
#
# wrong  : 597+6=593
# correct: 597+6=603
# outputs(x):  Te(3+133):126T
#
# wrong  : 3+133=126
# correct: 3+133=136
# outputs(x):  Te(375+8):373T
#
# wrong  : 375+8=373
# correct: 375+8=383
# outputs(x):  Te(229+3):222T
#
# wrong  : 229+3=222
# correct: 229+3=232
# outputs(x):  Te(9+122):121T
#
# wrong  : 9+122=121
# correct: 9+122=131
# outputs(x):  Te(13+47):50T
# j
# wrong  : 13+47=50
# correct: 13+47=60
# outputs(x):  Te(474+6):470T
#
# wrong  : 474+6=470
# correct: 474+6=480
# outputs(x):  Te(9+899):808T
#
# wrong  : 9+899=808
# correct: 9+899=908
# outputs(x):  Te(935+5):939T
#
# wrong  : 935+5=939
# correct: 935+5=940
# outputs(x):  Te(359+8):467T
#
# wrong  : 359+8=467
# correct: 359+8=367
# outputs(x):  Te(8+792):890T
#
# wrong  : 8+792=890
# correct: 8+792=800
# outputs(x):  Te(719+2):720T
#
# wrong  : 719+2=720
# correct: 719+2=721
# outputs(x):  Te(57+2):69T
# j
# wrong  : 57+2=69
# correct: 57+2=59
# outputs(x):  Te(4+86):80T
# F
# wrong  : 4+86=80
# correct: 4+86=90
# accuracy of 10000 examples: 9764/10000 (97.64%)
# {'carry0': 98.00747198007473, 'carry1': 96.94274596998332, 'carry2': 97.41784037558685, 'carry3': 99.56772334293949}
